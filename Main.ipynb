# %% [markdown]
# Подготовка данных и библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import ndcg_score
import lightgbm as lgb

# %%
data_set = pd.read_csv("intern_task.csv") # Потом заменить на ссылку

# %%
data_set.head() # посмотрим на это дело
# Out:
#    rank  query_id  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0     0        10        1.0        0.0        1.0        3.0        3.0
# 1     1        10        3.0        0.0        3.0        0.0        3.0
# 2     0        10        3.0        0.0        2.0        0.0        3.0
# 3     1        10        3.0        0.0        3.0        0.0        3.0
# 4     2        10        3.0        0.0        3.0        1.0        3.0
#
#    feature_5  feature_6  feature_7  ...  feature_134  feature_135  \
# 0   0.333333        0.0   0.333333  ...          0.0     0.000000
# 1   1.000000        0.0   1.000000  ...          0.0     0.000000
# 2   1.000000        0.0   0.666667  ...          0.0     0.000000
# 3   1.000000        0.0   1.000000  ...          0.0     0.000000
# 4   1.000000        0.0   1.000000  ...        273.0    79.670665
#
#    feature_136  feature_137  feature_138  feature_139  feature_140  \
# ...

# %% [markdown]
# Проанализируем датасет стандартными методами

# %%
data_set.describe()
# Out:
#                 rank       query_id      feature_0      feature_1  \
# count  235258.000000  235258.000000  235258.000000  235258.000000
# mean        0.677869   14828.413401       1.911960       0.206233
# std         0.830033    8193.945170       1.237374       0.579089
# min         0.000000      10.000000       0.000000       0.000000
# 25%         0.000000    8215.000000       1.000000       0.000000
# 50%         0.000000   14935.000000       2.000000       0.000000
# 75%         1.000000   21580.000000       3.000000       0.000000
# max         4.000000   29995.000000      31.000000      18.000000
#
#            feature_2      feature_3      feature_4      feature_5  \
# count  235258.000000  235258.000000  235258.000000  235258.000000
# mean        1.189847       0.550272       1.960082       0.803964
# std         1.037233       0.790947       1.203534       0.339955
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
data_set.nunique()
# Out:
# rank               5
# query_id        2000
# feature_0         16
# feature_1         10
# feature_2         15
#                ...
# feature_139       29
# feature_140    41864
# feature_141     4703
# feature_142      529
# feature_143     1431
# Length: 146, dtype: int64

# %%
data_set.corr()
# Out:
#                  rank  query_id  feature_0  feature_1  feature_2  feature_3  \
# rank         1.000000  0.074057  -0.034239   0.097110   0.177743   0.120893
# query_id     0.074057  1.000000  -0.040320  -0.019186  -0.004201   0.020878
# feature_0   -0.034239 -0.040320   1.000000   0.131044   0.560199   0.155114
# feature_1    0.097110 -0.019186   0.131044   1.000000   0.208730   0.196483
# feature_2    0.177743 -0.004201   0.560199   0.208730   1.000000   0.306295
# ...               ...       ...        ...        ...        ...        ...
# feature_139  0.149626  0.049949  -0.111323   0.134350   0.111337   0.833796
# feature_140  0.155181  0.034563  -0.047251   0.105877   0.189865   0.225540
# feature_141  0.001207 -0.005864   0.026149   0.016457   0.037717   0.036037
# feature_142  0.017734  0.001791   0.309202   0.114352   0.235129   0.084797
# feature_143  0.087033  0.011541   0.162987   0.182067   0.224031   0.138388
#
# ...

# %%
# Визуализация распределения категориальных признаков
for column in data_set.select_dtypes(include=['object']):
    plt.figure(figsize=(15, 10))
    data_set[column].value_counts().plot(kind='bar', color='red')
    plt.title(f'Распределение значений признака {column}')
    plt.xlabel(column)
    plt.ylabel('Частота')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Поскольку в датасете отсутствуют выбросы и пропущенные значения, можем сразу разбить данные на тренировочную и тестовую выборку. Для обучения будем использовать модель LambdaMART.

# %%
# Разделение данных на признаки (X) и целевую переменную (y), выделение query_id
X = data_set.drop(columns=['rank', 'query_id'], axis=1)
y = data_set['rank']
qids = data_set['query_id']

# Масштабирование признаков
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Разделение отмасштабированных данных на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Создание и тренировка модели LambdaMART
# Создание датасетов LightGBM
train_data = lgb.Dataset(X_train, label=y_train, group=qids)
val_data = lgb.Dataset(X_test, label=y_test, group=qids)

# Настройка параметров модели LambdaMART
params = {
    'objective': 'lambdarank',
    'metric': 'ndcg',  # Метрика для оценки качества модели
    'ndcg_eval_at': [10],  # Количество позиций для вычисления метрики NDCG
    'boosting_type': 'gbdt',  # Тип бустинга
    'num_leaves': 31,  # Количество листьев в деревьях
    'learning_rate': 0.1,  # Скорость обучения
    'min_data_in_leaf': 20,  # Минимальное количество данных в листе
    'verbose': 0  # Уровень вывода информации
}

# Обучение модели LambdaMART
num_round = 100  # Количество итераций обучения
bst = lgb.train(params, train_data, num_round, valid_sets=[val_data])

# %%
# Оценка качества модели на тестовом наборе
y_pred = bst.predict(X_test)
ndcg = ndcg_score(y_test, y_pred, k=10)
print("NDCG@10 on test set:", ndcg)
